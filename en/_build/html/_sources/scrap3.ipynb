# %% [markdown]
# <div style="float: right;">
#   <a href="../../../de/scrap3.html" style="margin-left: 10px;">🇩🇪 Deutsch</a>
#   <a href="../../../en/scrap3.html">🇬🇧 English</a>
# </div>
#
# # Third Environment
#
# Feel free to use any number of the following code cells to solve the tasks:

# %%
# import pandas as pd
# df = pd.read_csv("DOCUMENT_NAME.csv", sep=";", decimal=",")

# %%
# Your code goes here

# %%
# Your code goes here

# %%
# Your code goes here

# %%
# Your code goes here

# %%
# Your code goes here

# %%
# Your code goes here

# %%
# Your code goes here
